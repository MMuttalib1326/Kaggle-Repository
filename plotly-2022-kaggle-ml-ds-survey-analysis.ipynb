# %% [markdown]
# <a href="https://www.kaggle.com/code/mohdmuttalib/plotly-2022-kaggle-ml-ds-survey-analysis?scriptVersionId=136389739" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ## Contact Information
#
# - **Name** - Mohd Muttalib
# - **Phone** - +91-8445818187
# - **Email** - muttalib1326@gmail.com
# - **Portfolio** -[link](https://www.kaggle.com/mohdmuttalib)

# %% [markdown]
# ## Lets Start Our Analysis

# %%
# Importing Necessary Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from tqdm import tqdm
from warnings import filterwarnings
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True) 
filterwarnings('ignore')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Loading Data
raw_df = pd.read_csv('../input/kaggle-survey-2022/kaggle_survey_2022_responses.csv')

raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23998 entries, 0 to 23997
# Columns: 296 entries, Duration (in seconds) to Q44_12
# dtypes: object(296)
# memory usage: 54.2+ MB

# %%
# Dataset Sample
raw_df.head()
# Out:
#    Duration (in seconds)                           Q2  \
# 0  Duration (in seconds)  What is your age (# years)?
# 1                    121                        30-34
# 2                    462                        30-34
# 3                    293                        18-21
# 4                    851                        55-59
#
#                                        Q3  \
# 0  What is your gender? - Selected Choice
# 1                                     Man
# 2                                     Man
# 3                                     Man
# 4                                     Man
#
#                                           Q4  \
# 0  In which country do you currently reside?
# 1                                      India
# 2                                    Algeria
# 3                                      Egypt
# 4                                     France
#
#                                                   Q5  \
# ...

# %%
# Getting All Selected Options (Answers) in One Column
def get_unique_questions(raw_df):
    unique_que_list = list(set(list(map(lambda x: x.split('_')[0], list(raw_df.loc[:,raw_df.columns.str.contains('_')].columns)))))
    for que_no in tqdm(unique_que_list):
        raw_df[que_no] = raw_df.loc[:,raw_df.columns.str.contains(que_no)].apply(lambda x : '//'.join(x.dropna().astype(str)),axis=1)

get_unique_questions(raw_df)
# Out:
# 100%|██████████| 25/25 [02:01<00:00,  4.86s/it]

# %%
# Removing Columns Generated Due to Multiple Options

new_df = raw_df.drop(list(raw_df.loc[:,raw_df.columns.str.contains('_')].columns),axis=1)

for i in tqdm(range(5,len(new_df.columns))):
    new_df.iloc[:,i] = new_df.iloc[:,i].apply(lambda x : str(x).split('//'))

new_df['Counter'] = 1
# Out:
# 100%|██████████| 39/39 [00:01<00:00, 22.79it/s]

# %% [markdown]
# # Participants Around the World

# %%
data = [dict(
            type = 'choropleth',
            locations = new_df['Q4'].value_counts().index,
            z = new_df['Q4'].value_counts(),
            locationmode = 'country names',
            autocolorscale = True,
            marker = dict(
            line = dict(color = 'rgb(58,100,69)', width = 0.6)),
            colorbar = dict(autotick = True, tickprefix = '', title = 'No. of Participants')
            )
        ]

layout = dict(
                title = 'Participants Around the World',
                geo = dict(
                showframe = True,
                showcoastlines = True,
                showocean = True,
                showlakes = True,
                oceancolor = '#aef6f7',
                projection = dict(type = 'robinson'),
                margin = dict(b = 0, t = 0, l = 0, r = 0,pad= 5)),
                autosize = True
            )

fig = dict(data=data, layout=layout)

iplot(fig, validate=False)
# Out:
# <div>                            <div id="de6fc364-a1d2-4ae0-a0bb-e35f00ee26d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("de6fc364-a1d2-4ae0-a0bb-e35f00ee26d3")) {                    Plotly.newPlot(                        "de6fc364-a1d2-4ae0-a0bb-e35f00ee26d3",                        [{"type":"choropleth","locations":["India","United States of America","Other","Brazil","Nigeria","Pakistan","Japan","China","Egypt","Mexico","Indonesia","Turkey","Russia","South Korea","France","United Kingdom of Great Britain and Northern Ireland","Canada","Spain","Colombia","Bangladesh","Taiwan","Viet Nam","Argentina","Kenya","Italy","Morocco","Australia","Thailand","Tunisia","Peru","Iran, Islamic Republic of...","Chile","Poland","South Africa","Philippines","Ne
# ...

# %%
country_wise_participants_dict = new_df.loc[1:,'Q4'].value_counts()[:10].to_dict()
country_wise_participants_dict['Remaining Countries'] = sum(new_df.loc[1:,'Q4'].value_counts()[10:])

px.pie(pd.DataFrame({'Country':country_wise_participants_dict.keys(),'Count':country_wise_participants_dict.values()}),names='Country',values='Count',title='Country-wise Participation in Survey')
# Out:
# <div>                            <div id="f59c3f60-67ec-4a0d-8e2c-cffeadcbbdc6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f59c3f60-67ec-4a0d-8e2c-cffeadcbbdc6")) {                    Plotly.newPlot(                        "f59c3f60-67ec-4a0d-8e2c-cffeadcbbdc6",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Country=%{label}<br>Count=%{value}<extra></extra>","labels":["India","United States of America","Other","Brazil","Nigeria","Pakistan","Japan","China","Egypt","Mexico","Remaining Countries"],"legendgroup":"","name":"","showlegend":true,"values":[8792,2920,1430,833,731,620,556,453,383,380,6899],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colo
# ...

# %% [markdown]
# ## Like Experts Say, "India is going to be leading country in Industry 4.0". Numbers are speaking here. Around 36% of participants in survey were from the India followed by USA (12%).

# %% [markdown]
# # Aging Analysis

# %%
fig = px.bar(new_df.loc[1:,'Q2'].value_counts(),y='Q2',labels={'index':'Age','Q2':'Count','text':'Count'},text=(new_df.loc[1:,'Q2'].value_counts()) ,title='Participants Aging Analysis')
fig.show()
# Out:
# <div>                            <div id="f953164e-0894-4359-aca6-2151cea56dba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f953164e-0894-4359-aca6-2151cea56dba")) {                    Plotly.newPlot(                        "f953164e-0894-4359-aca6-2151cea56dba",                        [{"alignmentgroup":"True","hovertemplate":"Age=%{x}<br>Count=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[4559.0,4472.0,4283.0,2972.0,2353.0,1927.0,1253.0,914.0,611.0,526.0,127.0],"textposition":"auto","x":["18-21","25-29","22-24","30-34","35-39","40-44","45-49","50-54","55-59","60-69","70+"],"xaxis":"x","y":[4559,4472,4283,2972,2353,1927,1253,91
# ...

# %% [markdown]
# ## Most of the kagglers participated in survey are below the age of 25. Future of data science field looks bright when so many young people have already started exploring it.

# %% [markdown]
# # Gender

# %%
pd.DataFrame(new_df.loc[1:,'Q3'].value_counts()).reset_index().rename(columns={'index':'Gender','Q3':'Count'})
# Out:
#                     Gender  Count
# 0                      Man  18266
# 1                    Woman   5286
# 2        Prefer not to say    334
# 3                Nonbinary     78
# 4  Prefer to self-describe     33

# %%
fig = px.bar(new_df.loc[1:].groupby(['Q2','Q3']).sum().reset_index(), x="Q2", y="Counter", color="Q3", title="Age Group and Gender of Participants",labels={'Counter':'No. of Participants','Q2':'Age Range','Q3':'Gender'},text_auto=True)
fig.show()
# Out:
# <div>                            <div id="3ced8c54-662d-42e2-8af7-ed80014c604f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ced8c54-662d-42e2-8af7-ed80014c604f")) {                    Plotly.newPlot(                        "3ced8c54-662d-42e2-8af7-ed80014c604f",                        [{"alignmentgroup":"True","hovertemplate":"Gender=Man<br>Age Range=%{x}<br>No. of Participants=%{y}<extra></extra>","legendgroup":"Man","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Man","offsetgroup":"Man","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["18-21","22-24","25-29","30-34","35-39","40-44","45-49","50-54","55-59","60-69","70+"],"xaxis":"x","y":[3310,3168,3425,2248,1791,1480,997,759,506,470,112],"yaxis"
# ...

# %%
pd.pivot_table(new_df[1:],index='Q4',values='Counter',columns='Q3',aggfunc='count',).sort_values('Man',ascending=False)
# Out:
# Q3                                                     Man  Nonbinary  \
# Q4
# India                                               6488.0        5.0
# United States of America                            2047.0       34.0
# Other                                               1127.0        5.0
# Brazil                                               706.0        2.0
# Nigeria                                              548.0        NaN
# Pakistan                                             512.0        NaN
# Japan                                                504.0        2.0
# China                                                356.0        3.0
# Mexico                                               316.0        2.0
# Egypt                                                293.0        NaN
# Indonesia                                            266.0        NaN
# Turkey                                               261.0        1.0
# ...

# %% [markdown]
# ## Disappointed with womens participation. I was expecting better numbers. Womens participation around the world is only 22%.

# %% [markdown]
# # Students Participated in Survey

# %%
no_of_students = new_df['Q5'].value_counts()['Yes']
no_of_students_pct = (no_of_students / len(raw_df)) * 100

print('{} ({:.2f}%) Students participated in Survey.'.format(no_of_students,no_of_students_pct))
# Out:
# 11961 (49.84%) Students participated in Survey.

# %% [markdown]
# ## Surprised to know that 11961 (49.84%) Students participated in Survey. Thought that most of the  participants will be working professionals but looks like students are also being ready to jump start their career in data science.

# %%
dict1 = new_df[new_df['Q5']=='Yes']['Q4'].value_counts()[:5].to_dict()
dict1['Remaining Countries'] = new_df[new_df['Q5']=='Yes']['Q4'].value_counts()[5:].sum()

fig1 = px.bar(pd.DataFrame({'Country':dict1.keys(),'No of Participants':dict1.values()}), x='Country', y="No of Participants",text='No of Participants',barmode='group',
             height=700,title='Students Participation Worldwide')
fig1.show()

fig2 = px.pie(pd.DataFrame({'Country':dict1.keys(),'Participants':dict1.values()}), values='Participants',
             names='Country', title='Country-Wise Students Participants')

fig2.show()
# Out:
# <div>                            <div id="61ae052f-4e3b-41f6-9327-f6217ab35667" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("61ae052f-4e3b-41f6-9327-f6217ab35667")) {                    Plotly.newPlot(                        "61ae052f-4e3b-41f6-9327-f6217ab35667",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>No of Participants=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[4967.0,924.0,708.0,482.0,437.0,4443.0],"textposition":"auto","x":["India","United States of America","Other","Nigeria","Brazil","Remaining Countries"],"xaxis":"x","y":[4967,924,708,482,437,4443],"yaxis":"y","type":"bar"}],   
# ...

# %% [markdown]
# ## Although most of the students participants were from India, I am impressed with Nigerian student group. Keep it up buddies!

# %% [markdown]
# # Platform for Data Science Courses

# %%
ds_platforms_dict = new_df.explode('Q6').loc[1:,'Q6'].value_counts().to_dict()
ds_platforms_dict['University Courses'] = ds_platforms_dict.pop('University Courses (resulting in a university degree)')
ds_platforms_dict['Cloud Certification Programs'] = ds_platforms_dict.pop('Cloud-certification programs (direct from AWS, Azure, GCP, or similar)')

px.bar(pd.DataFrame({'Learning Platform':ds_platforms_dict.keys(),'No. of Users':ds_platforms_dict.values()}).sort_values('No. of Users',ascending=False),x='Learning Platform',y='No. of Users',color='No. of Users',text='No. of Users',title='Data Science Learning Platforms')
# Out:
# <div>                            <div id="c07187eb-45b6-4818-a594-cf30456e6157" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c07187eb-45b6-4818-a594-cf30456e6157")) {                    Plotly.newPlot(                        "c07187eb-45b6-4818-a594-cf30456e6157",                        [{"alignmentgroup":"True","hovertemplate":"Learning Platform=%{x}<br>No. of Users=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[9699,6780,6628,6116,5669,3718,2766,2643,2474,2199,1821,944],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[9699.0,6780.0,6628.0,6116.0,5669.0,3718.0,2766.0,2643.0,2474.0,2199.0,1821.0,944.0],"textposition":"auto","x":["Coursera","University Cour
# ...

# %% [markdown]
# ## Below are the top 3 platforms chosen by participants as there choice for learning data science. :
# 1) Coursera
# 2) University Courses (resulting in a university degree)
# 3) Kaggle Learn Courses

# %% [markdown]
# ## Lets help these learning platforms presenting them major number of their users around the globe.

# %%
learning_platforms_df = new_df.explode('Q6').loc[1:,]

coursera_dict = learning_platforms_df[learning_platforms_df['Q6']=='Coursera']['Q4'].value_counts()[:10].to_dict()
coursera_dict['Other Countries'] = sum(learning_platforms_df[learning_platforms_df['Q6']=='Coursera']['Q4'].value_counts()[10:])

universities_dict = learning_platforms_df[learning_platforms_df['Q6']=='University Courses (resulting in a university degree)']['Q4'].value_counts()[:10].to_dict()
universities_dict['Other Countries'] = sum(learning_platforms_df[learning_platforms_df['Q6']=='University Courses (resulting in a university degree)']['Q4'].value_counts()[10:])

kaggle_dict = learning_platforms_df[learning_platforms_df['Q6']=='Kaggle Learn Courses']['Q4'].value_counts()[:10].to_dict()
kaggle_dict['Other Countries'] = sum(learning_platforms_df[learning_platforms_df['Q6']=='Kaggle Learn Courses']['Q4'].value_counts()[10:])



fig1 = px.bar(pd.DataFrame({'Country':coursera_dict.keys(),'Participants':coursera_dict.values()}),x='Country',y='Participants',color='Participants',text='Participants', title='Coursera: Country-Wise Participants')
fig1.show()


fig2 = px.bar(pd.DataFrame({'Country':universities_dict.keys(),'Participants':universities_dict.values()}),x='Country',y='Participants',color='Participants',text='Participants', title='University Courses: Country-Wise Participants')
fig2.show()


fig3 = px.bar(pd.DataFrame({'Country':kaggle_dict.keys(),'Participants':kaggle_dict.values()}),x='Country',y='Participants',color='Participants',text='Participants', title='Kaggle Courses: Country-Wise Participants')
fig3.show()
# Out:
# <div>                            <div id="50ca03b0-5b09-45f7-b22e-aafc790c7a3b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("50ca03b0-5b09-45f7-b22e-aafc790c7a3b")) {                    Plotly.newPlot(                        "50ca03b0-5b09-45f7-b22e-aafc790c7a3b",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Participants=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[3073,1543,587,324,301,244,205,200,150,139,2933],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[3073.0,1543.0,587.0,324.0,301.0,244.0,205.0,200.0,150.0,139.0,2933.0],"textposition":"auto","x":["India","United States of America","Other","Brazil","Nigeria","
# ...

# %% [markdown]
# ## I will leave the business development job for these plaforms.🙂

# %% [markdown]
# # Learning Platform Preferred in Early Stage of Learning Data Science

# %%
new_df.loc[0,'Q7'][0].split(' -')[0]
early_stage_learning_platforms = new_df.explode('Q7').loc[1:,'Q7'].value_counts().to_dict()
learning_platforms_df = pd.DataFrame({'Learning Platform':early_stage_learning_platforms.keys(),'Count':early_stage_learning_platforms.values()})
fig = px.bar(learning_platforms_df,x='Learning Platform',y='Count',color='Count',text='Count',title='Learning Platforms Preferred at Early Stage in Learning DS')
fig.show()
# Out:
# <div>                            <div id="7afadb2e-a6e6-4160-8684-e1c2b45dc6bd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7afadb2e-a6e6-4160-8684-e1c2b45dc6bd")) {                    Plotly.newPlot(                        "7afadb2e-a6e6-4160-8684-e1c2b45dc6bd",                        [{"alignmentgroup":"True","hovertemplate":"Learning Platform=%{x}<br>Count=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[13714,12871,12700,6851,3310,1944,1022,301],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[13714.0,12871.0,12700.0,6851.0,3310.0,1944.0,1022.0,301.0],"textposition":"auto","x":["Online courses (Coursera, EdX, etc)","Video platforms (YouTube, Twitch, etc
# ...

# %%
# print('In their earlier stage of learning data science, below are the top 3 learning platforms preferred by the participants. :\n')
# print(new_df.explode('Q7')['Q7'].value_counts()[:3])

# %% [markdown]
# ## In their earlier stage of learning data science, below are the top 3 learning platforms preferred by the participants. :
#
# 1) Online courses (Coursera, EdX, etc)
# 2) Video platforms (YouTube, Twitch, etc)
# 3) Kaggle (notebooks, competitions, etc)

# %% [markdown]
# # Highest Level of Education

# %%
new_df.loc[0,'Q8'][0].split(' -')[0]

education_lvl = new_df.explode('Q8').loc[1:,'Q8'].value_counts().to_dict()

bachelors_degree_or_higher = ['Master’s degree', 'Bachelor’s degree', 'Doctoral degree','Professional doctorate']
bachelors_degree_or_higher_dict = {a : b for a,b in education_lvl.items() if a in bachelors_degree_or_higher}

highly_educated_participants = sum(bachelors_degree_or_higher_dict.values())

others = sum({l : m  for l,m in education_lvl.items() if l not in bachelors_degree_or_higher}.values())

ed_dict = bachelors_degree_or_higher_dict
ed_dict['Others'] = others

fig = px.pie(pd.DataFrame({'Education_Level':ed_dict.keys(),'No_of_Participants':ed_dict.values()}), values='No_of_Participants', names='Education_Level', title='Education Level of Participants')
fig.show()
# Out:
# <div>                            <div id="102f1480-c711-43a8-8759-dc67f1eaf540" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("102f1480-c711-43a8-8759-dc67f1eaf540")) {                    Plotly.newPlot(                        "102f1480-c711-43a8-8759-dc67f1eaf540",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Education_Level=%{label}<br>No_of_Participants=%{value}<extra></extra>","labels":["Master’s degree","Bachelor’s degree","Doctoral degree","Professional doctorate","Others"],"legendgroup":"","name":"","showlegend":true,"values":[9142,7625,2657,585,3988],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colo
# ...

# %% [markdown]
# ## More than 50% of kagglers say that their highest qualification level is Master's degree or above. 😯

# %% [markdown]
# # Publishing Research Work

# %%
new_df.loc[0,'Q9'][0].split(' -')[0]

countries_exploring_DS = new_df.explode('Q9')[new_df.explode('Q9')['Q9']=='Yes']['Q4'].value_counts()[:10].to_dict()
countries_exploring_DS['Other Countries'] = sum(new_df.explode('Q9')[new_df.explode('Q9')['Q9']=='Yes']['Q4'].value_counts()[10:])

fig = px.bar(pd.DataFrame({'Country':countries_exploring_DS.keys(),'Participants':countries_exploring_DS.values()}), x='Participants',
             y='Country', text ='Participants',title='Countries Publishing Research Work')

fig.show()
# Out:
# <div>                            <div id="4df6c742-6b46-49c6-8554-334426f5ef34" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4df6c742-6b46-49c6-8554-334426f5ef34")) {                    Plotly.newPlot(                        "4df6c742-6b46-49c6-8554-334426f5ef34",                        [{"alignmentgroup":"True","hovertemplate":"Participants=%{text}<br>Country=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"text":[1240.0,903.0,380.0,250.0,155.0,107.0,105.0,102.0,100.0,99.0,1803.0],"textposition":"auto","x":[1240,903,380,250,155,107,105,102,100,99,1803],"xaxis":"x","y":["India","United States of America","Other","Brazil","Japan","Turkey","Nig
# ...

# %% [markdown]
# ## Indians participation is not just only to add extra count but numbers validate that they are on first place in publishing research too.

# %%
yoe_n_research = new_df.loc[1:][['Q9','Q11','Q8']]

yoe_n_research['Q8'] = yoe_n_research['Q8'].apply(lambda x: x[0])
yoe_n_research['Q9'] = yoe_n_research['Q9'].apply(lambda x: x[0])
yoe_n_research['Q11'] = yoe_n_research['Q11'].apply(lambda x: x[0])

yoe_n_research.rename(columns={'Q8':'Highest Qualification','Q9':'Research Published','Q11':'YOE in Coding'},inplace=True)

fig = px.sunburst(data_frame=yoe_n_research,
                  path=['Research Published', 'YOE in Coding'],
                  color='Research Published',title='Research Published Based on Coding Experience in Years.')

fig.update_traces(textinfo='label+percent parent')
fig.update_layout(margin=dict(t=40, l=0, r=0, b=0))
fig.show()
# Out:
# <div>                            <div id="dee96ad6-7eb1-48a5-b59b-5671bc7bce4f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dee96ad6-7eb1-48a5-b59b-5671bc7bce4f")) {                    Plotly.newPlot(                        "dee96ad6-7eb1-48a5-b59b-5671bc7bce4f",                        [{"branchvalues":"total","customdata":[["nan"],["No"],["nan"],["Yes"],["nan"],["No"],["Yes"],["No"],["nan"],["Yes"],["Yes"],["No"],["nan"],["Yes"],["Yes"],["nan"],["Yes"],["nan"],["No"],["No"],["Yes"],["No"],["nan"],["Yes"],["No"],["nan"],["No"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<br>Research Published=%{customdata[0]}<extra></extra>","ids":["nan","No/nan","nan/10-20 years","Yes
# ...

# %% [markdown]
# ## Like many of us, I was guessing about people who are doing research and pusblished papers, preprints, conference proceedings, etc. , would be having more than 5-10 years of coding experience.
# ## But Here is what the fact is. Because of huge learning resources available nowadys and most importantly its fast accessibility due to internet, people are thinking beyond, going for innovations. And hence research field has participations coming from people who are in early stage of their career.

# %%
fig = px.sunburst(data_frame=yoe_n_research,
                  path=['Research Published', 'Highest Qualification'],
                  color='Research Published',title='Research Published and Highest Qualification.')

fig.update_traces(textinfo='label+percent parent')
fig.update_layout(margin=dict(t=40, l=0, r=0, b=0))
fig.show()
# Out:
# <div>                            <div id="5f57fa0b-8de4-445e-b1c9-222838126246" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f57fa0b-8de4-445e-b1c9-222838126246")) {                    Plotly.newPlot(                        "5f57fa0b-8de4-445e-b1c9-222838126246",                        [{"branchvalues":"total","customdata":[["No"],["nan"],["No"],["Yes"],["nan"],["nan"],["nan"],["nan"],["No"],["Yes"],["No"],["Yes"],["nan"],["nan"],["Yes"],["nan"],["nan"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<br>Research Published=%{customdata[0]}<extra></extra>","ids":["No","nan/Some college/university study without earning a bachelor’s degree","No/Master’s degree","Yes/Professio
# ...

# %% [markdown]
# ## Data science practioners having education level as Master's Degree or higher are ahead in publishing their academic research like papers, preprints, conference proceedings, etc.

# %% [markdown]
# # Application of Machine Learning in Research

# %%
new_df.loc[0,'Q10'][0].split(' -')[0]

research_dict = new_df.explode('Q10').loc[1:,'Q10'].value_counts().to_dict()

research_dict.pop('')
research_dict['Yes (Used as a Tool)'] = research_dict.pop('Yes, the research made use of machine learning as a tool (applied research)')
research_dict['Yes (Theoretical Research)'] = research_dict.pop('Yes, the research made advances related to some novel machine learning method (theoretical research)')
fig = px.pie(pd.DataFrame({'Used ML ?':research_dict.keys(),'No_of_Participants':research_dict.values()}), values='No_of_Participants', names='Used ML ?', title='Application of ML in Research')
fig.show()
# Out:
# <div>                            <div id="b27d5365-a383-4289-8dbd-4dc11cfcf922" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b27d5365-a383-4289-8dbd-4dc11cfcf922")) {                    Plotly.newPlot(                        "b27d5365-a383-4289-8dbd-4dc11cfcf922",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Used ML ?=%{label}<br>No_of_Participants=%{value}<extra></extra>","labels":["No","Yes (Used as a Tool)","Yes (Theoretical Research)"],"legendgroup":"","name":"","showlegend":true,"values":[1913,2463,1549],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#4
# ...

# %% [markdown]
# ## Based on valid responses received (5925), 4012(67.71%) researchers confirmed application of machine learning in their research.

# %%
no_of_researchers = sum(new_df.explode('Q10')[(new_df.explode('Q10')['Q10'].str.startswith('Yes')) | (new_df.explode('Q10')['Q10'].str.startswith('No'))]['Q10'].value_counts())

using_ml_for_research = new_df.explode('Q10')[new_df.explode('Q10')['Q10'].str.startswith('Yes')]['Q23'].apply(lambda x:x[0]).value_counts().to_dict()

fig = px.bar(pd.DataFrame({'Job Title':using_ml_for_research.keys(),'No of Participants':using_ml_for_research.values()}), x='Job Title', y="No of Participants",text='No of Participants',barmode='group',
             height=700,title='Application of ML in Research By Different Job Titles')
fig.show()
# Out:
# <div>                            <div id="01f6e8d6-0267-4ea5-8ed5-8ec06f02d748" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01f6e8d6-0267-4ea5-8ed5-8ec06f02d748")) {                    Plotly.newPlot(                        "01f6e8d6-0267-4ea5-8ed5-8ec06f02d748",                        [{"alignmentgroup":"True","hovertemplate":"Job Title=%{x}<br>No of Participants=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[1773.0,569.0,447.0,402.0,185.0,152.0,130.0,108.0,58.0,54.0,40.0,36.0,31.0,12.0,10.0,5.0],"textposition":"auto","x":["nan","Data Scientist","Teacher / professor","Research Scientist","Machine Learning/ MLops Engineer","Manag
# ...

# %%
researchers_using_ml_in_research = new_df.explode('Q10')[new_df.explode('Q10')['Q10'].str.startswith('Yes')]['Q9'].value_counts()[0]

# %% [markdown]
# ## Data scientists are the ones leveraging machine learning the most in research work.

# %% [markdown]
# # Programming Languages Used by Data Science Practioners

# %%
new_df.loc[0,'Q12'][0].split(' -')[0]


fig = px.treemap(new_df.explode('Q12').loc[1:,'Q12'].value_counts(), path=[new_df.explode('Q12').loc[1:,'Q12'].value_counts().index] ,values=new_df.explode('Q12').loc[1:,'Q12'].value_counts(),labels={'labels':'Language','value':'No. of Users'},title='Programming Languages Used Mostly')
fig.update_traces(root_color="lightgrey")
fig.update_layout(margin = dict(t=50, l=25, r=25, b=25))
fig.show()
# Out:
# <div>                            <div id="c7829ce2-69f1-46b6-b2f4-b7d4749997c6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c7829ce2-69f1-46b6-b2f4-b7d4749997c6")) {                    Plotly.newPlot(                        "c7829ce2-69f1-46b6-b2f4-b7d4749997c6",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Language=%{label}<br>value=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["","Bash","C","C#","C++","Go","Java","Javascript","Julia","MATLAB","None","Other","PHP","Python","R","SQL"],"labels":["","Bash","C","C#","C++","Go","Java","Javascript","Julia","MATLAB","None","Other","PHP","Python","R","SQL"],"name":"","parents":["","","","","","","","","","","","","","","",""],
# ...

# %%
python_users = new_df.explode('Q12')[new_df.explode('Q12')['Q12']=='Python']['Q23'].apply(lambda x:x[0]).value_counts().to_dict()
sql_users = new_df.explode('Q12')[new_df.explode('Q12')['Q12']=='SQL']['Q23'].apply(lambda x:x[0]).value_counts().to_dict()
r_users = new_df.explode('Q12')[new_df.explode('Q12')['Q12']=='R']['Q23'].apply(lambda x:x[0]).value_counts().to_dict()

fig1 = px.pie(pd.DataFrame({'Job Title':python_users.keys(),'Users':python_users.values()}), values='Users', names='Job Title', title='Python Users')
fig1.show()

fig2 = px.pie(pd.DataFrame({'Job Title':sql_users.keys(),'Users':sql_users.values()}), values='Users', names='Job Title', title='SQL Users')
fig2.show()

fig3 = px.pie(pd.DataFrame({'Job Title':r_users.keys(),'Users':r_users.values()}), values='Users', names='Job Title', title='R Users')
fig3.show()
# Out:
# <div>                            <div id="8a9cec52-6347-4d5e-b218-d5e8f275d5a6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8a9cec52-6347-4d5e-b218-d5e8f275d5a6")) {                    Plotly.newPlot(                        "8a9cec52-6347-4d5e-b218-d5e8f275d5a6",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Job Title=%{label}<br>Users=%{value}<extra></extra>","labels":["nan","Data Scientist","Data Analyst (Business, Marketing, Financial, Quantitative, etc)","Currently not employed","Software Engineer","Teacher / professor","Manager (Program, Project, Operations, Executive-level, etc)","Machine Learning/ MLops Engineer","Research Scientist","Other","Data Engineer","Engineer (non-software)","Data Architect","Sta
# ...

# %% [markdown]
# ## Python is the most used programming lanuage by data science practioners followed by SQL and R.

# %% [markdown]
# # Mostly Used IDE's

# %%
new_df.loc[0,'Q13'][0].split(' -')[0]

ide_dict = new_df.explode('Q13').loc[1:,'Q13'].value_counts().to_dict()

ide_df = pd.DataFrame({'IDE':ide_dict.keys(),'No. of Users':ide_dict.values()})

ide_df
# Out:
#                               IDE  No. of Users
# 0                Jupyter Notebook         13684
# 1    Visual Studio Code (VSCode)           9976
# 2                        PyCharm           6099
# 3                     JupyterLab           4887
# 4                  Visual Studio           4416
# 5                     Notepad++            3891
# 6                        RStudio           3824
# 7                                          3405
# 8                        Spyder            2880
# 9                         MATLAB           2302
# 10                 Sublime Text            2218
# 11                       IntelliJ          1612
# 12                          Other          1474
# 13                  Vim / Emacs            1448
# 14                           None           409

# %%
px.bar(pd.DataFrame({'IDE':ide_dict.keys(),'No. of Users':ide_dict.values()}),x='IDE',y='No. of Users',text='No. of Users',title='IDE\'s by Number of Users')
# Out:
# <div>                            <div id="dc10570d-5153-4db0-8c19-2dd0863eda86" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dc10570d-5153-4db0-8c19-2dd0863eda86")) {                    Plotly.newPlot(                        "dc10570d-5153-4db0-8c19-2dd0863eda86",                        [{"alignmentgroup":"True","hovertemplate":"IDE=%{x}<br>No. of Users=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[13684.0,9976.0,6099.0,4887.0,4416.0,3891.0,3824.0,3405.0,2880.0,2302.0,2218.0,1612.0,1474.0,1448.0,409.0],"textposition":"auto","x":[" Jupyter Notebook"," Visual Studio Code (VSCode) "," PyCharm ","JupyterLab "," Visual Studio ","  Not
# ...

# %% [markdown]
# ## Jupyter Notebook, Visual Studio Code (VSCode), Pycharm are the most favoured integrated development environments (IDE).

# %% [markdown]
# # Hosted Notebook Products

# %%
new_df.loc[0,'Q14'][0].split(' -')[0]

new_df.explode('Q14')['Q14'].value_counts()[:5]

colab_n_kaggle_users = new_df.explode('Q14')['Q14'].value_counts()[:2].sum()
colab_n_kaggle_users_pct = (colab_n_kaggle_users / len(raw_df)) * 100

# print(f'Total number of Colab and Kaggle Notebook Users: {colab_n_kaggle_users}')
# print('{:.2f} % of people using Colab and Kaggle notebooks.'.format(colab_n_kaggle_users_pct))

# %% [markdown]
# ## Colab and Kaggle notebooks are found to be chosen the most by kagglers.

# %% [markdown]
# # Highly Preferred Python Visualization Libraries

# %%
new_df.loc[0,'Q15'][0].split(' -')[0]

viz_lib_df = pd.DataFrame(new_df.explode('Q15').loc[1:,'Q15'].value_counts()).reset_index().rename(columns={'index':'Visualization Library','Q15':'No. of Users'})

px.scatter(viz_lib_df,x='Visualization Library',y='No. of Users',size='No. of Users',title='Visualization Libraries by No. of Users')
# Out:
# <div>                            <div id="ba811aac-3dae-4943-8887-15f55b971586" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba811aac-3dae-4943-8887-15f55b971586")) {                    Plotly.newPlot(                        "ba811aac-3dae-4943-8887-15f55b971586",                        [{"hovertemplate":"Visualization Library=%{x}<br>No. of Users=%{marker.size}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","size":[14010,10512,5078,4232,4145,3439,1167,1043,771,734,691,554,318,300,225,198],"sizemode":"area","sizeref":35.025,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[" Matplotlib "," Seaborn "," Plotly / Plotly Express ",""," Ggplot / ggplot2 ","None"," Geoplotlib "," Shiny "," Bokeh "," D
# ...

# %% [markdown]
# ## 'Matplotlib', 'Seaborn' and 'Plotly/Plotly Express' are the most used Python libraries for data visualization.

# %% [markdown]
# # Mostly Used ML Frameworks

# %%
new_df.loc[0,'Q17'][0].split(' -')[0]

ml_fmworks_dict = new_df.explode('Q17').loc[1:,'Q17'].value_counts().to_dict()

ml_fmworks_df = pd.DataFrame({'ML Framework':ml_fmworks_dict.keys(),'No. of Users':ml_fmworks_dict.values()})


px.scatter(ml_fmworks_df,x='ML Framework',y='No. of Users',size='No. of Users', title='ML Frameworks by No. of Users')
# Out:
# <div>                            <div id="ac984caa-6eb2-4baf-bc0c-dc46508deff4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac984caa-6eb2-4baf-bc0c-dc46508deff4")) {                    Plotly.newPlot(                        "ac984caa-6eb2-4baf-bc0c-dc46508deff4",                        [{"hovertemplate":"ML Framework=%{x}<br>No. of Users=%{marker.size}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","size":[11403,7953,7757,6575,5191,4477,1940,1709,1332,1165,1013,821,648,620,547,252],"sizemode":"area","sizeref":28.5075,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["  Scikit-learn ","  TensorFlow ",""," Keras "," PyTorch "," Xgboost "," LightGBM ","None"," Huggingface "," CatBoost "," PyTorch 
# ...

# %% [markdown]
# ## Scikit-learn followed by Tensorflow are the most used ML frameworks.

# %% [markdown]
# # Highly Used ML Algorithms

# %%
new_df.loc[0,'Q18'][0].split(' -')[0]

highly_used_ml_algorithms = list(new_df.explode('Q18').loc[1:,'Q18'].value_counts()[:6].index)

highly_used_ml_algorithms.pop(2)



# print('Following are the top 5 highly used Machine Learning Algorithms.:\n')
# for algo in highly_used_ml_algorithms: print(algo)
# Out:
# ''

# %%
algo_for_research_dict = new_df.explode('Q9')[new_df.explode('Q9')['Q9']=='Yes'].explode('Q18')['Q18'].value_counts().to_dict()

px.bar(pd.DataFrame({'Algorithm':algo_for_research_dict.keys(),'Count':algo_for_research_dict.values()}),x='Algorithm',y='Count',text='Count',title='ML Algorithms Used by People Who Have Published Their Research Work')
# Out:
# <div>                            <div id="f869d9f6-ec1d-4a14-b0c9-39a8321cf8dd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f869d9f6-ec1d-4a14-b0c9-39a8321cf8dd")) {                    Plotly.newPlot(                        "f869d9f6-ec1d-4a14-b0c9-39a8321cf8dd",                        [{"alignmentgroup":"True","hovertemplate":"Algorithm=%{x}<br>Count=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[3048.0,2588.0,1978.0,1744.0,1199.0,1196.0,1156.0,1004.0,838.0,562.0,495.0,436.0,362.0,180.0,148.0],"textposition":"auto","x":["Linear or Logistic Regression","Decision Trees or Random Forests","Convolutional Neural Networks","Gradient B
# ...

# %% [markdown]
# ## Following are the top 5 mostly used Machine Learning Algorithms.:
#
# 1) Linear or Logistic Regression
# 2) Decision Trees or Random Forests
# 3) Convolutional Neural Networks
# 4) Gradient Boosting Machines (xgboost, lightgbm, etc)
# 5) Bayesian Approaches

# %% [markdown]
# ## Linear regression model is still mostly used machine learning algorithm in research.

# %% [markdown]
# # Computer Vision Application

# %%
new_df.loc[0,'Q19'][0].split(' -')[0]

new_df.loc[0,'Q19'][0].split(' -')[0]

pd.DataFrame(new_df.explode('Q19').loc[1:,'Q19'].value_counts()[1:]).reset_index().rename(columns={'index':'Computer Vision Method','Q19':'No. of Users'})
# Out:
#                               Computer Vision Method  No. of Users
# 0  Image classification and other general purpose...          3664
# 1  Object detection methods (YOLOv6, RetinaNet, etc)          2525
# 2  Image segmentation methods (U-Net, Mask R-CNN,...          2495
# 3  General purpose image/video tools (PIL, cv2, s...          2293
# 4                                               None          1455
# 5                Generative Networks (GAN, VAE, etc)          1343
# 6  Vision transformer networks (ViT, DeiT, BiT, B...           782
# 7                                              Other           146

# %% [markdown]
# ## Fast exploring computer vision technologies are highly getting used for image classification and other general purpose networks like VGG, Inception, ResNet, ResNeXt, NASNet, EfficientNet, etc.

# %% [markdown]
# # ML Model Hubs / Repositories

# %%
new_df.loc[0,'Q22'][0].split(' -')[0]

repositories_df = pd.DataFrame(new_df.explode('Q22').loc[1:,'Q22'].value_counts()[1:]).reset_index().rename(columns={'index':'Repository','Q22':'Count'})

fig = px.bar(repositories_df,x='Repository',y='Count',color='Count',text='Count',title='Pupular ML MOdel Hubs / Repositories')
fig.show()
# Out:
# <div>                            <div id="5ce40cd0-1d48-4df1-a499-335854a18196" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ce40cd0-1d48-4df1-a499-335854a18196")) {                    Plotly.newPlot(                        "5ce40cd0-1d48-4df1-a499-335854a18196",                        [{"alignmentgroup":"True","hovertemplate":"Repository=%{x}<br>Count=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[1618,799,502,412,127,96,69,46,24],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[1618.0,799.0,502.0,412.0,127.0,96.0,69.0,46.0,24.0],"textposition":"auto","x":[" Kaggle datasets ","  TensorFlow Hub "," Huggingface Models "," PyTorch Hub "," Timm ","Other stor
# ...

# %% [markdown]
# ## Kaggle dataset repository being used widely, helping researchers/data science enthusiast to explore the DS technologies.

# %% [markdown]
# # Job Titles

# %%
new_df.loc[0,'Q23'][0].split(' -')[0]

job_titles_df = pd.DataFrame(new_df.explode('Q23').loc[1:,'Q23'].value_counts()).reset_index().rename(columns={'index':'Job Title','Q23':'Count'})

job_titles_df.replace({'Data Analyst (Business, Marketing, Financial, Quantitative, etc)':'Data Analyst','Manager (Program, Project, Operations, Executive-level, etc)':'Manager'},inplace=True)

px.pie(job_titles_df,names='Job Title',values='Count')
# Out:
# <div>                            <div id="362f3b71-50c7-43c4-b730-02be38bea375" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("362f3b71-50c7-43c4-b730-02be38bea375")) {                    Plotly.newPlot(                        "362f3b71-50c7-43c4-b730-02be38bea375",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Job Title=%{label}<br>Count=%{value}<extra></extra>","labels":["nan","Data Scientist","Data Analyst","Currently not employed","Software Engineer","Teacher / professor","Manager","Other","Research Scientist","Machine Learning/ MLops Engineer","Engineer (non-software)","Data Engineer","Statistician","Data Architect","Data Administrator","Developer Advocate"],"legendgroup":"","name":"","showlegend":true,"value
# ...

# %% [markdown]
# ## It would have been great to know people are working with which title. But looks like people want to keep it confidential. 😏

# %% [markdown]
# # Researchers and Their Job Titles

# %%
researchers_title = pd.DataFrame(new_df.explode('Q9')[new_df.explode('Q9')['Q9']=='Yes']['Q23'].apply(lambda x:x[0]).value_counts()).reset_index().rename(columns={'index':'Job Title','Q23':'Count'})

px.bar(researchers_title,x='Job Title',y='Count',text='Count',color='Count')
# Out:
# <div>                            <div id="0708461f-0060-4ff8-a08a-dd1553e29677" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0708461f-0060-4ff8-a08a-dd1553e29677")) {                    Plotly.newPlot(                        "0708461f-0060-4ff8-a08a-dd1553e29677",                        [{"alignmentgroup":"True","hovertemplate":"Job Title=%{x}<br>Count=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[2116,705,556,445,255,230,190,176,173,147,106,62,46,16,14,7],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[2116.0,705.0,556.0,445.0,255.0,230.0,190.0,176.0,173.0,147.0,106.0,62.0,46.0,16.0,14.0,7.0],"textposition":"auto","x":["nan","Data Scientist","Teacher / 
# ...

# %% [markdown]
# ## Data scientists remain at the top place in data science research work followed by teachers/professors.

# %% [markdown]
# # Salary Comparison Based on Coding Experience

# %% [markdown]
# ### Based on the 2787 not-null responses, below chart shows the salaries offered by organizations

# %%
new_df.loc[0,'Q29'][0].split(' -')[0]


salaries = new_df.explode('Q29').loc[1:,'Q29'].value_counts()[1:].to_dict()

fig = px.bar(pd.DataFrame({'Salary Range':salaries.keys(),'Count':salaries.values()}), x='Count', y="Salary Range",barmode='group',
             height=700,title='Salaries Offered for Data Science Roles')
fig.show()
# Out:
# <div>                            <div id="ab395e5c-49e5-4d74-92bb-902fd5565c3f" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ab395e5c-49e5-4d74-92bb-902fd5565c3f")) {                    Plotly.newPlot(                        "ab395e5c-49e5-4d74-92bb-902fd5565c3f",                        [{"alignmentgroup":"True","hovertemplate":"Count=%{x}<br>Salary Range=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[1112,493,464,444,421,404,391,366,362,342,337,318,299,289,277,271,269,244,234,222,197,155,78,76,48,23],"xaxis":"x","y":["$0-999","10,000-14,999","30,000-39,999","1,000-1,999","40,000-49,999","100,000-124,999","5,000-7,
# ...

# %% [markdown]
# ## Salary Based on YOE in Coding

# %%
salary_df = new_df.explode('Q11').loc[1:]

salary_df['Q29'] = salary_df['Q29'].apply(lambda x : x[0])

salary_df['Q11'].replace({'nan':np.nan},inplace=True)
salary_df['Q29'].replace({'nan':np.nan},inplace=True)

salary_df['Q29'].value_counts()

salary_df_new = salary_df.dropna(subset=['Q11'])
salary_df_new = salary_df.dropna(subset=['Q29'])

salary_df_new['counter'] = 1

salary_df_new.rename(columns={'Q11':'YOE in Coding','Q29':'Salary Range'},inplace=True)

pd.pivot_table(salary_df_new,index='Salary Range',values='counter',columns='YOE in Coding',aggfunc='count').style.bar(color = "lightblue",vmin = 0).set_properties(**{'border': '0.5px solid black'})
# Out:
# <style type="text/css">
# #T_d7272_row0_col0, #T_d7272_row0_col3, #T_d7272_row0_col4, #T_d7272_row0_col5, #T_d7272_row0_col6, #T_d7272_row4_col1, #T_d7272_row7_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightblue 100.0%, transparent 100.0%);
#   border: 0.5px solid black;
# }
# #T_d7272_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightblue 73.3%, transparent 73.3%);
#   border: 0.5px solid black;
# }
# #T_d7272_row0_col2, #T_d7272_row20_col2 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightblue 57.4%, transparent 57.4%);
#   border: 0.5px solid black;
# }
# #T_d7272_row1_col0 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightblue 2.5%, transparent 2.5%);
#   border: 0.5px solid black;
# }
# #T_d7272_row1_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,lightblue 10.0%, transparent 10.0%);
#   border: 0.5px solid black;
# ...

# %% [markdown]
# ## As expected, figures validate that with more experience in coding, people are most likely to obtain higher salary packages. But still there are few organizations who are paying well for freshers too.

# %% [markdown]
# # Money Spent on ML/Cloud Computing Services

# %%
new_df.loc[0,'Q30'][0].split(' -')[0]

money_spent_on_ml = new_df.explode('Q30').loc[1:,'Q30'].value_counts().to_dict()

money_spent_on_ml['No Response'] = money_spent_on_ml.pop('nan')

ml_cost = px.pie(pd.DataFrame({'Money Spent':money_spent_on_ml.keys(),'Count':money_spent_on_ml.values()}),values='Count',names='Money Spent')
ml_cost.update_layout(legend_title_text='Cost Spent',title='Money Spent on ML')
# Out:
# <div>                            <div id="7526712f-0032-4ea7-8635-ba3a771cf857" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7526712f-0032-4ea7-8635-ba3a771cf857")) {                    Plotly.newPlot(                        "7526712f-0032-4ea7-8635-ba3a771cf857",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Money Spent=%{label}<br>Count=%{value}<extra></extra>","labels":["$0 ($USD)","$100-$999","$1000-$9,999","$1-$99","$10,000-$99,999","$100,000 or more ($USD)","No Response"],"legendgroup":"","name":"","showlegend":true,"values":[2822,2078,1469,1449,480,186,15513],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":
# ...
